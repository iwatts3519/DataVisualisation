# %% [markdown]
# # Course Name: Visualisation for Data Analytics
# # Objective: Multivariate Data Visulization (Part 2)

# %%
# Import the desired libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Q1. Load Excercise data from 'seaborn' package and print the attributes of the dataset? Familiarize yourself with the dataset.

# %%
exercise_df = sns.load_dataset("exercise")
exercise_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  90 non-null     int64
#  1   id          90 non-null     int64
#  2   diet        90 non-null     category
#  3   pulse       90 non-null     int64
#  4   time        90 non-null     category
#  5   kind        90 non-null     category
# dtypes: category(3), int64(3)
# memory usage: 2.9 KB

# %%
exercise_df.describe()
# Out:
#        Unnamed: 0         id       pulse
# count   90.000000  90.000000   90.000000
# mean    44.500000  15.500000   99.700000
# std     26.124701   8.703932   14.858471
# min      0.000000   1.000000   80.000000
# 25%     22.250000   8.000000   90.250000
# 50%     44.500000  15.500000   96.000000
# 75%     66.750000  23.000000  103.000000
# max     89.000000  30.000000  150.000000

# %%
exercise_df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %% [markdown]
# ## Q2. Compare the percenatge of  people takink 'low fat' and 'No Fat' diet?

# %%
low_fat_count = exercise_df['diet'].value_counts()['low fat']
no_fat_count = exercise_df['diet'].value_counts()['no fat']
total_rows = exercise_df.shape[0]
low_fat_per =  (low_fat_count*100)/total_rows
no_fat_per =  (no_fat_count*100)/total_rows
print('low fat percentage=', low_fat_per, 'no fat percentage=', no_fat_per)

count = [low_fat_per, no_fat_per]
labels = ['low_fat_per', 'no_fat_per']
plt.bar(  labels, count, color='pink')
# Out:
# low fat percentage= 50.0 no fat percentage= 50.0
# <BarContainer object of 2 artists>

# %% [markdown]
# ## Q3. Plot Time Vs Pulse as scatter plot and write your interpretation from the graph and type of correlation that you see?

# %%
import numpy
import matplotlib.pyplot as plt

x = exercise_df['time']
y = exercise_df['pulse']

plt.scatter(x, y)
plt.show()

# %%
sns.scatterplot(data=exercise_df, x="time", y="pulse")
# Out:
# <AxesSubplot:xlabel='time', ylabel='pulse'>

# %% [markdown]
# ## Q4.Make scatter plot using time, pulse, and kind variable and the relation between different variables?

# %%
import seaborn as sns

sns.catplot(x="time", y="pulse", hue="kind", data=exercise_df)

## Now you can see the pulse is varying depending on whether the persion is resting, walking or running

# %% [markdown]
# ## Q5. Make a box plot using 'pulse' feature and indentify mean? Also, comment on the number of outlier visible?

# %%
boxplot = exercise_df.boxplot(column=['pulse'])
'''
From the graph you can see that the median is somewhere between 90 to 100. The pulse value above 120 are
considered as outlier. There are around 8 outliers.
'''
# Out:
# '\nFrom the graph you can see that the median is somewhere between 90 to 100. The pulse value above 120 are\nconsidered as outlier. There are around 8 outliers.\n'

# %% [markdown]
# ## Q6. Load the 'Iris' data set from seaborn package and familiarize yourself with dataset?

# %%
import pandas as pd
import seaborn as sns
iris_df=sns.load_dataset('iris')
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Q7. Make violin plot using of the 'sepal_length' attribute. Make a violin for each 'species'. Like the following:
# ![image.png](attachment:image.png)

# %%
# Using matplot lib

import matplotlib.pyplot as plt


setosa =  iris_df[iris_df['species']=='setosa']['sepal_length']
versicolor =  iris_df[iris_df['species']=='versicolor']['sepal_length']
virginica =  iris_df[iris_df['species']=='virginica']['sepal_length']
data_to_plot = [setosa, versicolor, virginica]

plt.violinplot(data_to_plot)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x139d7b2cc10>,
# ...
#  'cmaxes': <matplotlib.collections.LineCollection at 0x139d7b2ca30>,
#  'cmins': <matplotlib.collections.LineCollection at 0x139d8746760>,
#  'cbars': <matplotlib.collections.LineCollection at 0x139d8746ac0>}

# %%
## Using seaborn
sns.violinplot(x='species',y='sepal_length',data=iris_df,size=6)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# ## Q7. Make a heat map using 'sepal_length', 'sepal_width', 'petal_length', 'petal_width' attributes. For that you first nees to find  the correlation between these 4 attribute and then use thod correlation value for making heat map. (Note: if you dont know about correlation then please read the tutorial here https://www.bmj.com/about-bmj/resources-readers/publications/statistics-square-one/11-correlation-and-regression)

# %%
iris_df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
ax = sns.heatmap(iris_df.corr())

# %% [markdown]
# # Question 8: Make pairwise scatter of all features like following:
# ![image.png](attachment:image.png)
#
# Now, use dimention reduction (e.g., PCA) and scatter plot the new features pairs. Now you will observe that only two features are sufficient to classify the iris data.

# %%
import plotly.express as px

df = px.data.iris()
features = ["sepal_width", "sepal_length", "petal_width", "petal_length"]

fig = px.scatter_matrix(
    df,
    dimensions=features,
    color="species"
)
fig.update_traces(diagonal_visible=True)
fig.show()

# %%
import plotly.express as px
from sklearn.decomposition import PCA

df = px.data.iris()
features = ["sepal_width", "sepal_length", "petal_width", "petal_length"]

pca = PCA()
components = pca.fit_transform(df[features])
labels = {
    str(i): f"PC {i+1} ({var:.1f}%)"
    for i, var in enumerate(pca.explained_variance_ratio_ * 100)
}

fig = px.scatter_matrix(
    components,
    labels=labels,
    dimensions=range(4),
    color=df["species"]
)
fig.update_traces(diagonal_visible=True)
fig.show()

# %% [markdown]
# ## credit for heat map. There are more plots available here
# ## link: https://www.kaggle.com/rakesh6184/seaborn-plot-to-visualize-iris-data
# # Credit for Pairwise Scatter: https://plotly.com/python/pca-visualization/
